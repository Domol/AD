# %% [markdown]
# ## Zadanie
#
# Wylosuj próbkę 1000-elementową liczb pseudolosowych zgodnie z modelem przedstawionym na wykładzie.

# %%
import numpy as np
import numpy.random as rnd
import matplotlib.pyplot as plt
import scipy.stats as stats
from numpy import linalg as LA

a=1234123
c=643563
m=6557
def generate(n):
    x=1424523565
    res = []
    for i in range(n):
        x = (a*x+c)%m
        res.append(x/m)
    return res
x = generate(100)
plt.plot(x)
plt.show()

# %% [markdown]
# ## Zadanie
# Wylosuj próbkę 1000-elementową z rozkładu jednostajnego na odcinku (wykorzystując kod z Zad 1.).

# %%
def generate_unif(a,b):
    return [a+(b-a)*x for x in generate(1000)]
# print(generate_unif(1,5))

# %% [markdown]
# ## Zadanie
# Wylosuj próbkę 1000-elementową z rozkładu normalnego za pomocą metody odwrotnej do dystrybuanty http://staff.iiar.pwr.wroc.pl/grzegorz.mzyk/kmi/kmi03.pdf.

# %%
xs = generate(1000)
y = [stats.norm.cdf(x=a,loc=0.5,scale=1) for a in xs]

# %% [markdown]
# ## Zadanie
#
# Wylosuj próbkę 1000-elementową z rozkładów
#
#   * N(0,1^2)
#   * N(3,3^2)
#   * Unif(0,1)
#   * Unif(-1,1)
#   * Gamma(1,2)
#   * LogN(.08,2^2)
#
# i narysuj histogram

# %%
import numpy as np
import numpy.random as rnd
import matplotlib.pyplot as plt
import scipy.stats as stats
from numpy import linalg as LA
import scipy.stats as stats

def draw_hist(x):
    plt.hist(x, bins = 30)
    plt.show()
    
draw_hist(np.random.normal(0, 1, 10000))

# %% [markdown]
# ## Zadanie
# Narysuj histogram oraz gęstość rozkładu LogN

# %%
s= 0.9
x = stats.lognorm.rvs(s, size=1000)
pdfx = np.linspace(0, 10, 200)
pdfy = stats.lognorm.pdf(pdfx, 1)
plt.hist(x, bins = 30, normed=1)
plt.plot(pdfx, pdfy, 'r-', label='PDF')
plt.show()

# %% [markdown]
# ## Zadanie
#
# Wylosuj próbkę z dwuwymiarowego rozkładu normalnego

# %%
y = np.random.multivariate_normal(np.array((0,0)), np.array([[1,0],[0,1]]), 1000)
plt.scatter(y[:,0],y[:,1])
plt.show()

# %% [markdown]
# ## Zadanie
#
# Narysuj wykres 3d gęstości dwuwymiarowego rozkładu normalnego.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from mpl_toolkits.mplot3d import Axes3D

#Parameters to set
mu_x = 0
variance_x = 4

mu_y = 0
variance_y = 4

#Create grid and multivariate normal
x = np.linspace(-7,7,500)
y = np.linspace(-7,7,500)
X, Y = np.meshgrid(x,y)
pos = np.empty(X.shape + (2,))
pos[:, :, 0] = X; pos[:, :, 1] = Y
rv = multivariate_normal([mu_x, mu_y], [[variance_x, 0], [0, variance_y]])

#Make a 3D plot
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, rv.pdf(pos),cmap='viridis',linewidth=0)
plt.show()

# %% [markdown]
# ## Zadanie
#
# Prosze narysować poziomicę dwuwymiarowego rozkładu normalnego.

# %%
import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

matplotlib.rcParams['xtick.direction'] = 'out'
matplotlib.rcParams['ytick.direction'] = 'out'

delta = 0.025
x = np.arange(-6.0, 6.0, delta)
y = np.arange(-4.0, 4.0, delta)
X, Y = np.meshgrid(x, y)
Z = mlab.bivariate_normal(X, Y, 2.0, 1.0, 0.0, 0.0)


plt.figure()
CS = plt.contour(X, Y, Z)
plt.clabel(CS, inline=1, fontsize=10)
plt.show()

# %% [markdown]
# ## Zadanie
# Pobierz dowolne zdjęcie i narysuj histogram z danych dla każdego z komponentów RGB.

# %%
from scipy.ndimage import imread
im = imread('image.jpg', flatten=False, mode='RGB').reshape((589*883*3))
print(im)
plt.hist(im, bins=100)
plt.show()
# Out:
# [133 184 249 ...,  73  78  37]

# %% [markdown]
# ## Zadanie
# Pobierz dowolny plik z dźwiękiem i narysuj histogram pliki.

# %%
import numpy as np
import scipy.io.wavfile

sound = scipy.io.wavfile.read('sound.wav', mmap=False)
plt.hist(sound[1][:,0], bins=50)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/scipy/io/wavfile.py:273: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)

# %% [markdown]
# ## Zadanie
# Niech $X = (x_1, \ldots , x_N )$, $Y = (y_1, \ldots , y_K)$. Znamy srednią i wariancję $X$ oraz
# $Y$. Proszę wyliczyć srednią i wariancję $X \cup Y = (x_1, \ldots , x_N , y_1, \ldots , y_K)$.
#
# Aby wyliczyc srednia sumy zbiorów liczymy srednia z wagami:
#
# $mean(X \cup Y) = \frac{mean(X) \cdot |X| + mean(Y) \cdot |Y|}{|X|+|Y|}$

# %% [markdown]
# # Zadanie
#
# Proszę policzyć medianę $X = \{1, 2, 5, 2, 3\}$.

# %% [markdown]
# ## Odp
#
#
# Aby obliczyć medianę sortujemy liczby:
#
# $X = \{1, 2, 2, 3, 5\}$
#
# Medianą jest środkowa liczba, czyli: 2

# %% [markdown]
# ## Przykład
# Użyj testu kstest do obliczenia wartości p-value.

# %%
x = rnd.randn(1000)
plt.hist(x)
plt.show()
kstest = stats.kstest
stat, pval = kstest(x, 'norm')
print(stat)
print(pval)
if(pval < 0.05):
    print("Odrzucam hipotezę zerową na poziomie istotności 0.05")
else:    
    print("Nie ma podstaw by odrzucić hipotezę zerową  na poziomie istotności 0.05")
# Out:
# 0.0232786313478
# 0.650538654971
# Nie ma podstaw by odrzucić hipotezę zerową  na poziomie istotności 0.05
